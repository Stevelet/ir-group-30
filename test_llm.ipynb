# %%
import pyterrier as pt
import json
import numpy as np
from scipy.spatial.distance import jensenshannon
import matplotlib.pyplot as plt
import ast
import pandas as pd
import ir_datasets
if not pt.started():
    pt.init(tqdm="notebook")

# %% [markdown]
# # 1. Define evaluation metrics

# %%
def dcg(scores, k):
    return np.sum([(rel / np.log2(idx + 2)) for idx, rel in enumerate(scores[:k], start=1)])

def calculate_ndcg(ranked_list, n):
    """
    Calculate the nDCG of a result set
    result_df: DataFrame. The dataframe containing the results
    """
    scores = [rank[1]['qrel'] for rank in ranked_list][0:n]
    
    ideal_scores = sorted(scores, reverse=True)
    DCG = dcg(scores, n)
    IDCG = dcg(ideal_scores, n)
    if IDCG >0:
        return DCG/IDCG
    else:
        return 0
    
def disc(k):
    """
    The discount function used in the nDCG/AWRF
    """
    return 1 / np.log2(max(k, 2))

def calculate_awrf(ranked_list, expected_distribution, attribute, n=10):
    """
    Calculate the AWRF of a result set
    result_df: DataFrame. The dataframe containing the results
    expected_distribution: Dict. The distribution of the dataset. e.g.
            {'Man': 1494634,
            'Woman': 353495,
            'Non-binary': 781,
            'Unknown': 4605703,
            'null': 0}
    attribute: Str. The attribute to consider. e.g. 'gender'
    n: Int.  refer to the number of documents to consider
    """
    current_distribution = {key: 0 for key in expected_distribution}
    for index, row in ranked_list:
        if index<n:
            if row[attribute]:
                current_distribution[row[attribute]]+= disc(index+1)
            else:
                current_distribution['null']+= disc(index+1)
    
    desired_distribution = np.array(list(expected_distribution.values()))
    current_distribution = np.array(list(current_distribution.values()))

    target_distr = desired_distribution/np.sum(desired_distribution)
    current_distr = current_distribution/np.sum(current_distribution)
    awrf = 1- jensenshannon(target_distr, current_distr)**2
    return awrf

# %% [markdown]
# # 2. Obtain dataset distribution of genderfor AWRF and NDCG calculation

# %%
import os
import json

index_root = os.path.join(os.getcwd(), '..', '..', '..', '..', '..', '..', '..', '..', 'media', 'steve', 'PortableSSD', 'index')

distribution_file = os.path.join(index_root, 'distribution.json')

with open(distribution_file, 'r') as fp:
    dataset_distribution = json.load(fp)
    
dataset_distribution
# Out:
# {'Man': 1495328, 'Woman': 353642, 'Non-binary': 781}

# %% [markdown]
# # 3. Retrieve and evaluation

# %%
llm_ranking_file = os.path.join(index_root, 'llm_ranking.json')

with open(llm_ranking_file, 'r') as fp:
    llm_ranking = json.load(fp)
    
llm_ranking
# Out:
# {'4': [[0, {'gender_category': 'Man', 'qrel': 0.45942733}],
#   [1, {'gender_category': 'Man', 'qrel': 0.34803268}],
#   [2, {'gender_category': 'Woman', 'qrel': 0.43804768}],
#   [3, {'gender_category': 'Woman', 'qrel': 0.41044617}],
#   [4, {'gender_category': 'Woman', 'qrel': 0.57402503}],
#   [5, {'gender_category': 'Woman', 'qrel': 0.22064358}],
#   [6, {'gender_category': 'Man', 'qrel': 0.44185033}],
#   [7, {'gender_category': 'Woman', 'qrel': 0.34168866}],
#   [8, {'gender_category': 'Man', 'qrel': 0.2258933}],
#   [9, {'gender_category': 'Man', 'qrel': 0.4571543}],
#   [10, {'gender_category': 'Woman', 'qrel': 0.24468344}],
#   [11, {'gender_category': 'Man', 'qrel': 0.53643125}],
#   [12, {'gender_category': 'Woman', 'qrel': 0.27914345}],
#   [13, {'gender_category': 'Man', 'qrel': 0.2753966}],
#   [14, {'gender_category': 'Man', 'qrel': 0.5608159}],
#   [15, {'gender_category': 'Man', 'qrel': 0.47655153}],
#   [16, {'gender_category': 'Man', 'qrel': 0.38892874}],
#   [17, {'gender_category': 'Man', 'qrel': 0.23532997}],
#   [18, {'gender_category': 'Man', 'qrel': 0.33026832}],
#   [19, {'gender_category': 'Man', 'qrel': 0.3740489}],
#   [20, {'gender_category': 'Man', 'qrel': 0.43481043}],
#   [21, {'gender_category': 'Man', 'qrel': 0.4204094}],
#   [22, {'gender_category': 'Woman', 'qrel': 0.46305355}],
#   [23, {'gender_category': 'Woman', 'qrel': 0.4503662}],
#   [24, {'gender_category': 'Man', 'qrel': 0.49320835}],
#   [25, {'gender_category': 'Man', 'qrel': 0.32841942}],
#   [26, {'gender_category': 'Man', 'qrel': 0.2882122}],
#   [27, {'gender_category': 'Man', 'qrel': 0.28622663}],
#   [28, {'gender_category': 'Man', 'qrel': 0.23590045}],
#   [29, {'gender_category': 'Man', 'qrel': 0.3595189}],
#   [30, {'gender_category': 'Woman', 'qrel': 0.40245545}],
#   [31, {'gender_category': 'Man', 'qrel': 0.5339396}],
#   [32, {'gender_category': 'Man', 'qrel': 0.48222297}],
#   [33, {'gender_category': 'Man', 'qrel': 0.3106056}],
#   [34, {'gender_category': 'Man', 'qrel': 0.42562854}],
#   [35, {'gender_category': 'Man', 'qrel': 0.3271555}],
#   [36, {'gender_category': 'Man', 'qrel': 0.32964346}],
#   [37, {'gender_category': 'Man', 'qrel': 0.63109887}],
#   [38, {'gender_category': 'Woman', 'qrel': 0.24697436}],
#   [39, {'gender_category': 'Woman', 'qrel': 0.4521132}],
#   [40, {'gender_category': 'Woman', 'qrel': 0.3319268}],
#   [41, {'gender_category': 'Man', 'qrel': 0.26309234}],
#   [42, {'gender_category': 'Man', 'qrel': 0.5237337}],
#   [43, {'gender_category': 'Man', 'qrel': 0.24055849}],
#   [44, {'gender_category': 'Man', 'qrel': 0.5468121}],
#   [45, {'gender_category': 'Man', 'qrel': 0.52380484}],
#   [46, {'gender_category': 'Man', 'qrel': 0.5069892}],
#   [47, {'gender_category': 'Man', 'qrel': 0.44300774}],
#   [48, {'gender_category': 'Man', 'qrel': 0.458946}],
#   [49, {'gender_category': 'Man', 'qrel': 0.38758564}],
#   [50, {'gender_category': 'Man', 'qrel': 0.27436957}],
#   [51, {'gender_category': 'Woman', 'qrel': 0.4127303}],
#   [52, {'gender_category': 'Woman', 'qrel': 0.46450529}],
#   [53, {'gender_category': 'Man', 'qrel': 0.55062485}],
#   [54, {'gender_category': 'Woman', 'qrel': 0.39373443}],
#   [55, {'gender_category': 'Woman', 'qrel': 0.51454204}],
#   [56, {'gender_category': 'Woman', 'qrel': 0.43069243}],
#   [57, {'gender_category': 'Man', 'qrel': 0.3955581}],
#   [58, {'gender_category': 'Man', 'qrel': 0.29795262}],
#   [59, {'gender_category': 'Man', 'qrel': 0.30457345}],
#   [60, {'gender_category': 'Man', 'qrel': 0.43100142}],
#   [61, {'gender_category': 'Man', 'qrel': 0.35531348}],
#   [62, {'gender_category': 'Man', 'qrel': 0.388517}],
#   [63, {'gender_category': 'Man', 'qrel': 0.31084383}],
#   [64, {'gender_category': 'Woman', 'qrel': 0.47425985}],
#   [65, {'gender_category': 'Man', 'qrel': 0.4610618}],
#   [66, {'gender_category': 'Man', 'qrel': 0.35993266}],
#   [67, {'gender_category': 'Man', 'qrel': 0.3706792}],
#   [68, {'gender_category': 'Man', 'qrel': 0.2604132}],
#   [69, {'gender_category': 'Man', 'qrel': 0.41326267}],
#   [70, {'gender_category': 'Man', 'qrel': 0.5146256}],
#   [71, {'gender_category': 'Man', 'qrel': 0.2526895}],
#   [72, {'gender_category': 'Man', 'qrel': 0.43834662}],
#   [73, {'gender_category': 'Man', 'qrel': 0.40986368}],
#   [74, {'gender_category': 'Woman', 'qrel': 0.2761447}],
#   [75, {'gender_category': 'Man', 'qrel': 0.31829968}],
#   [76, {'gender_category': 'Man', 'qrel': 0.317396}],
#   [77, {'gender_category': 'Woman', 'qrel': 0.66895163}],
#   [78, {'gender_category': 'Man', 'qrel': 0.35586476}],
#   [79, {'gender_category': 'Man', 'qrel': 0.3593474}],
#   [80, {'gender_category': 'Man', 'qrel': 0.4867743}],
#   [81, {'gender_category': 'Man', 'qrel': 0.5955202}],
#   [82, {'gender_category': 'Man', 'qrel': 0.5581189}],
#   [83, {'gender_category': 'Man', 'qrel': 0.47577876}],
#   [84, {'gender_category': 'Woman', 'qrel': 0.20125288}],
#   [85, {'gender_category': 'Man', 'qrel': 0.43121052}],
#   [86, {'gender_category': 'Man', 'qrel': 0.30958351}],
#   [87, {'gender_category': 'Man', 'qrel': 0.5821266}],
#   [88, {'gender_category': 'Woman', 'qrel': 0.45179084}],
#   [89, {'gender_category': 'Man', 'qrel': 0.29954115}],
#   [90, {'gender_category': 'Man', 'qrel': 0.5407688}],
#   [91, {'gender_category': 'Man', 'qrel': 0.45719725}],
#   [92, {'gender_category': 'Man', 'qrel': 0.4517407}],
#   [93, {'gender_category': 'Man', 'qrel': 0.2740803}],
#   [94, {'gender_category': 'Man', 'qrel': 0.38225725}],
#   [95, {'gender_category': 'Woman', 'qrel': 0.26231098}],
#   [96, {'gender_category': 'Man', 'qrel': 0.3398841}],
#   [97, {'gender_category': 'Man', 'qrel': 0.3000102}],
#   [98, {'gender_category': 'Man', 'qrel': 0.26333693}],
#   [99, {'gender_category': 'Man', 'qrel': 0.25286597}]],
#  '5': [[0, {'gender_category': 'Man', 'qrel': 0.45942733}],
#   [1, {'gender_category': 'Man', 'qrel': 0.34803268}],
#   [2, {'gender_category': 'Woman', 'qrel': 0.43804768}],
#   [3, {'gender_category': 'Woman', 'qrel': 0.41044617}],
#   [4, {'gender_category': 'Woman', 'qrel': 0.57402503}],
#   [5, {'gender_category': 'Woman', 'qrel': 0.22064358}],
#   [6, {'gender_category': 'Man', 'qrel': 0.44185033}],
#   [7, {'gender_category': 'Woman', 'qrel': 0.34168866}],
#   [8, {'gender_category': 'Man', 'qrel': 0.2258933}],
#   [9, {'gender_category': 'Man', 'qrel': 0.4571543}],
#   [10, {'gender_category': 'Woman', 'qrel': 0.24468344}],
#   [11, {'gender_category': 'Man', 'qrel': 0.53643125}],
#   [12, {'gender_category': 'Woman', 'qrel': 0.27914345}],
#   [13, {'gender_category': 'Man', 'qrel': 0.2753966}],
#   [14, {'gender_category': 'Man', 'qrel': 0.5608159}],
#   [15, {'gender_category': 'Man', 'qrel': 0.47655153}],
#   [16, {'gender_category': 'Man', 'qrel': 0.38892874}],
#   [17, {'gender_category': 'Man', 'qrel': 0.23532997}],
#   [18, {'gender_category': 'Man', 'qrel': 0.33026832}],
#   [19, {'gender_category': 'Man', 'qrel': 0.3740489}],
#   [20, {'gender_category': 'Man', 'qrel': 0.43481043}],
#   [21, {'gender_category': 'Man', 'qrel': 0.4204094}],
#   [22, {'gender_category': 'Woman', 'qrel': 0.46305355}],
#   [23, {'gender_category': 'Woman', 'qrel': 0.4503662}],
#   [24, {'gender_category': 'Man', 'qrel': 0.49320835}],
#   [25, {'gender_category': 'Man', 'qrel': 0.32841942}],
#   [26, {'gender_category': 'Man', 'qrel': 0.2882122}],
#   [27, {'gender_category': 'Man', 'qrel': 0.28622663}],
#   [28, {'gender_category': 'Man', 'qrel': 0.23590045}],
#   [29, {'gender_category': 'Man', 'qrel': 0.3595189}],
#   [30, {'gender_category': 'Woman', 'qrel': 0.40245545}],
#   [31, {'gender_category': 'Man', 'qrel': 0.5339396}],
#   [32, {'gender_category': 'Man', 'qrel': 0.48222297}],
#   [33, {'gender_category': 'Man', 'qrel': 0.3106056}],
#   [34, {'gender_category': 'Man', 'qrel': 0.42562854}],
#   [35, {'gender_category': 'Man', 'qrel': 0.3271555}],
#   [36, {'gender_category': 'Man', 'qrel': 0.32964346}],
#   [37, {'gender_category': 'Man', 'qrel': 0.63109887}],
#   [38, {'gender_category': 'Woman', 'qrel': 0.24697436}],
#   [39, {'gender_category': 'Woman', 'qrel': 0.4521132}],
#   [40, {'gender_category': 'Woman', 'qrel': 0.3319268}],
#   [41, {'gender_category': 'Man', 'qrel': 0.26309234}],
#   [42, {'gender_category': 'Man', 'qrel': 0.5237337}],
#   [43, {'gender_category': 'Man', 'qrel': 0.24055849}],
#   [44, {'gender_category': 'Man', 'qrel': 0.5468121}],
#   [45, {'gender_category': 'Man', 'qrel': 0.52380484}],
#   [46, {'gender_category': 'Man', 'qrel': 0.5069892}],
#   [47, {'gender_category': 'Man', 'qrel': 0.44300774}],
#   [48, {'gender_category': 'Man', 'qrel': 0.458946}],
#   [49, {'gender_category': 'Man', 'qrel': 0.38758564}],
#   [50, {'gender_category': 'Man', 'qrel': 0.27436957}],
#   [51, {'gender_category': 'Woman', 'qrel': 0.4127303}],
#   [52, {'gender_category': 'Woman', 'qrel': 0.46450529}],
#   [53, {'gender_category': 'Man', 'qrel': 0.55062485}],
#   [54, {'gender_category': 'Woman', 'qrel': 0.39373443}],
#   [55, {'gender_category': 'Woman', 'qrel': 0.51454204}],
#   [56, {'gender_category': 'Woman', 'qrel': 0.43069243}],
#   [57, {'gender_category': 'Man', 'qrel': 0.3955581}],
#   [58, {'gender_category': 'Man', 'qrel': 0.29795262}],
#   [59, {'gender_category': 'Man', 'qrel': 0.30457345}],
#   [60, {'gender_category': 'Man', 'qrel': 0.43100142}],
#   [61, {'gender_category': 'Man', 'qrel': 0.35531348}],
#   [62, {'gender_category': 'Man', 'qrel': 0.388517}],
#   [63, {'gender_category': 'Man', 'qrel': 0.31084383}],
#   [64, {'gender_category': 'Woman', 'qrel': 0.47425985}],
#   [65, {'gender_category': 'Man', 'qrel': 0.4610618}],
#   [66, {'gender_category': 'Man', 'qrel': 0.35993266}],
#   [67, {'gender_category': 'Man', 'qrel': 0.3706792}],
#   [68, {'gender_category': 'Man', 'qrel': 0.2604132}],
#   [69, {'gender_category': 'Man', 'qrel': 0.41326267}],
#   [70, {'gender_category': 'Man', 'qrel': 0.5146256}],
#   [71, {'gender_category': 'Man', 'qrel': 0.2526895}],
#   [72, {'gender_category': 'Man', 'qrel': 0.43834662}],
#   [73, {'gender_category': 'Man', 'qrel': 0.40986368}],
#   [74, {'gender_category': 'Woman', 'qrel': 0.2761447}],
#   [75, {'gender_category': 'Man', 'qrel': 0.31829968}],
#   [76, {'gender_category': 'Man', 'qrel': 0.317396}],
#   [77, {'gender_category': 'Woman', 'qrel': 0.66895163}],
#   [78, {'gender_category': 'Man', 'qrel': 0.35586476}],
#   [79, {'gender_category': 'Man', 'qrel': 0.3593474}],
#   [80, {'gender_category': 'Man', 'qrel': 0.4867743}],
#   [81, {'gender_category': 'Man', 'qrel': 0.5955202}],
#   [82, {'gender_category': 'Man', 'qrel': 0.5581189}],
#   [83, {'gender_category': 'Man', 'qrel': 0.47577876}],
#   [84, {'gender_category': 'Woman', 'qrel': 0.20125288}],
#   [85, {'gender_category': 'Man', 'qrel': 0.43121052}],
#   [86, {'gender_category': 'Man', 'qrel': 0.30958351}],
#   [87, {'gender_category': 'Man', 'qrel': 0.5821266}],
#   [88, {'gender_category': 'Woman', 'qrel': 0.45179084}],
#   [89, {'gender_category': 'Man', 'qrel': 0.29954115}],
#   [90, {'gender_category': 'Man', 'qrel': 0.5407688}],
#   [91, {'gender_category': 'Man', 'qrel': 0.45719725}],
#   [92, {'gender_category': 'Man', 'qrel': 0.4517407}],
#   [93, {'gender_category': 'Man', 'qrel': 0.2740803}],
#   [94, {'gender_category': 'Man', 'qrel': 0.38225725}],
#   [95, {'gender_category': 'Woman', 'qrel': 0.26231098}],
#   [96, {'gender_category': 'Man', 'qrel': 0.3398841}],
#   [97, {'gender_category': 'Man', 'qrel': 0.3000102}],
#   [98, {'gender_category': 'Man', 'qrel': 0.26333693}],
#   [99, {'gender_category': 'Man', 'qrel': 0.25286597}]],
#  '6': [[0, {'gender_category': 'Man', 'qrel': 0.45942733}],
#   [1, {'gender_category': 'Man', 'qrel': 0.34803268}],
#   [2, {'gender_category': 'Woman', 'qrel': 0.43804768}],
#   [3, {'gender_category': 'Woman', 'qrel': 0.41044617}],
#   [4, {'gender_category': 'Woman', 'qrel': 0.57402503}],
#   [5, {'gender_category': 'Woman', 'qrel': 0.22064358}],
#   [6, {'gender_category': 'Man', 'qrel': 0.44185033}],
#   [7, {'gender_category': 'Woman', 'qrel': 0.34168866}],
#   [8, {'gender_category': 'Man', 'qrel': 0.2258933}],
#   [9, {'gender_category': 'Man', 'qrel': 0.4571543}],
#   [10, {'gender_category': 'Woman', 'qrel': 0.24468344}],
#   [11, {'gender_category': 'Man', 'qrel': 0.53643125}],
#   [12, {'gender_category': 'Woman', 'qrel': 0.27914345}],
#   [13, {'gender_category': 'Man', 'qrel': 0.2753966}],
#   [14, {'gender_category': 'Man', 'qrel': 0.5608159}],
#   [15, {'gender_category': 'Man', 'qrel': 0.47655153}],
#   [16, {'gender_category': 'Man', 'qrel': 0.38892874}],
#   [17, {'gender_category': 'Man', 'qrel': 0.23532997}],
#   [18, {'gender_category': 'Man', 'qrel': 0.33026832}],
#   [19, {'gender_category': 'Man', 'qrel': 0.3740489}],
#   [20, {'gender_category': 'Man', 'qrel': 0.43481043}],
#   [21, {'gender_category': 'Man', 'qrel': 0.4204094}],
#   [22, {'gender_category': 'Woman', 'qrel': 0.46305355}],
#   [23, {'gender_category': 'Woman', 'qrel': 0.4503662}],
#   [24, {'gender_category': 'Man', 'qrel': 0.49320835}],
#   [25, {'gender_category': 'Man', 'qrel': 0.32841942}],
#   [26, {'gender_category': 'Man', 'qrel': 0.2882122}],
#   [27, {'gender_category': 'Man', 'qrel': 0.28622663}],
#   [28, {'gender_category': 'Man', 'qrel': 0.23590045}],
#   [29, {'gender_category': 'Man', 'qrel': 0.3595189}],
#   [30, {'gender_category': 'Woman', 'qrel': 0.40245545}],
#   [31, {'gender_category': 'Man', 'qrel': 0.5339396}],
#   [32, {'gender_category': 'Man', 'qrel': 0.48222297}],
#   [33, {'gender_category': 'Man', 'qrel': 0.3106056}],
#   [34, {'gender_category': 'Man', 'qrel': 0.42562854}],
#   [35, {'gender_category': 'Man', 'qrel': 0.3271555}],
#   [36, {'gender_category': 'Man', 'qrel': 0.32964346}],
#   [37, {'gender_category': 'Man', 'qrel': 0.63109887}],
#   [38, {'gender_category': 'Woman', 'qrel': 0.24697436}],
#   [39, {'gender_category': 'Woman', 'qrel': 0.4521132}],
#   [40, {'gender_category': 'Woman', 'qrel': 0.3319268}],
#   [41, {'gender_category': 'Man', 'qrel': 0.26309234}],
#   [42, {'gender_category': 'Man', 'qrel': 0.5237337}],
#   [43, {'gender_category': 'Man', 'qrel': 0.24055849}],
#   [44, {'gender_category': 'Man', 'qrel': 0.5468121}],
#   [45, {'gender_category': 'Man', 'qrel': 0.52380484}],
#   [46, {'gender_category': 'Man', 'qrel': 0.5069892}],
#   [47, {'gender_category': 'Man', 'qrel': 0.44300774}],
#   [48, {'gender_category': 'Man', 'qrel': 0.458946}],
#   [49, {'gender_category': 'Man', 'qrel': 0.38758564}],
#   [50, {'gender_category': 'Man', 'qrel': 0.27436957}],
#   [51, {'gender_category': 'Woman', 'qrel': 0.4127303}],
#   [52, {'gender_category': 'Woman', 'qrel': 0.46450529}],
#   [53, {'gender_category': 'Man', 'qrel': 0.55062485}],
#   [54, {'gender_category': 'Woman', 'qrel': 0.39373443}],
#   [55, {'gender_category': 'Woman', 'qrel': 0.51454204}],
#   [56, {'gender_category': 'Woman', 'qrel': 0.43069243}],
#   [57, {'gender_category': 'Man', 'qrel': 0.3955581}],
#   [58, {'gender_category': 'Man', 'qrel': 0.29795262}],
#   [59, {'gender_category': 'Man', 'qrel': 0.30457345}],
#   [60, {'gender_category': 'Man', 'qrel': 0.43100142}],
#   [61, {'gender_category': 'Man', 'qrel': 0.35531348}],
#   [62, {'gender_category': 'Man', 'qrel': 0.388517}],
#   [63, {'gender_category': 'Man', 'qrel': 0.31084383}],
#   [64, {'gender_category': 'Woman', 'qrel': 0.47425985}],
#   [65, {'gender_category': 'Man', 'qrel': 0.4610618}],
#   [66, {'gender_category': 'Man', 'qrel': 0.35993266}],
#   [67, {'gender_category': 'Man', 'qrel': 0.3706792}],
#   [68, {'gender_category': 'Man', 'qrel': 0.2604132}],
#   [69, {'gender_category': 'Man', 'qrel': 0.41326267}],
#   [70, {'gender_category': 'Man', 'qrel': 0.5146256}],
#   [71, {'gender_category': 'Man', 'qrel': 0.2526895}],
#   [72, {'gender_category': 'Man', 'qrel': 0.43834662}],
#   [73, {'gender_category': 'Man', 'qrel': 0.40986368}],
#   [74, {'gender_category': 'Woman', 'qrel': 0.2761447}],
#   [75, {'gender_category': 'Man', 'qrel': 0.31829968}],
#   [76, {'gender_category': 'Man', 'qrel': 0.317396}],
#   [77, {'gender_category': 'Woman', 'qrel': 0.66895163}],
#   [78, {'gender_category': 'Man', 'qrel': 0.35586476}],
#   [79, {'gender_category': 'Man', 'qrel': 0.3593474}],
#   [80, {'gender_category': 'Man', 'qrel': 0.4867743}],
#   [81, {'gender_category': 'Man', 'qrel': 0.5955202}],
#   [82, {'gender_category': 'Man', 'qrel': 0.5581189}],
#   [83, {'gender_category': 'Man', 'qrel': 0.47577876}],
#   [84, {'gender_category': 'Woman', 'qrel': 0.20125288}],
#   [85, {'gender_category': 'Man', 'qrel': 0.43121052}],
#   [86, {'gender_category': 'Man', 'qrel': 0.30958351}],
#   [87, {'gender_category': 'Man', 'qrel': 0.5821266}],
#   [88, {'gender_category': 'Woman', 'qrel': 0.45179084}],
#   [89, {'gender_category': 'Man', 'qrel': 0.29954115}],
#   [90, {'gender_category': 'Man', 'qrel': 0.5407688}],
#   [91, {'gender_category': 'Man', 'qrel': 0.45719725}],
#   [92, {'gender_category': 'Man', 'qrel': 0.4517407}],
#   [93, {'gender_category': 'Man', 'qrel': 0.2740803}],
#   [94, {'gender_category': 'Man', 'qrel': 0.38225725}],
#   [95, {'gender_category': 'Woman', 'qrel': 0.26231098}],
#   [96, {'gender_category': 'Man', 'qrel': 0.3398841}],
#   [97, {'gender_category': 'Man', 'qrel': 0.3000102}],
#   [98, {'gender_category': 'Man', 'qrel': 0.26333693}],
#   [99, {'gender_category': 'Man', 'qrel': 0.25286597}]],
#  '17': [[0, {'gender_category': 'Man', 'qrel': 0.30334318}],
#   [1, {'gender_category': 'Man', 'qrel': 0.30479053}],
#   [2, {'gender_category': 'Man', 'qrel': 0.45942733}],
#   [3, {'gender_category': 'Man', 'qrel': 0.27401802}],
#   [4, {'gender_category': 'Man', 'qrel': 0.29654545}],
#   [5, {'gender_category': 'Man', 'qrel': 0.34803268}],
#   [6, {'gender_category': 'Man', 'qrel': 0.3310975}],
#   [7, {'gender_category': 'Man', 'qrel': 0.33696705}],
#   [8, {'gender_category': 'Woman', 'qrel': 0.43804768}],
#   [9, {'gender_category': 'Man', 'qrel': 0.44572663}],
#   [10, {'gender_category': 'Woman', 'qrel': 0.42190984}],
#   [11, {'gender_category': 'Man', 'qrel': 0.35733193}],
#   [12, {'gender_category': 'Man', 'qrel': 0.34237295}],
#   [13, {'gender_category': 'Man', 'qrel': 0.28343654}],
#   [14, {'gender_category': 'Man', 'qrel': 0.4618199}],
#   [15, {'gender_category': 'Woman', 'qrel': 0.41044617}],
#   [16, {'gender_category': 'Woman', 'qrel': 0.57402503}],
#   [17, {'gender_category': 'Woman', 'qrel': 0.39619765}],
#   [18, {'gender_category': 'Man', 'qrel': 0.32934362}],
#   [19, {'gender_category': 'Woman', 'qrel': 0.22064358}],
#   [20, {'gender_category': 'Man', 'qrel': 0.44185033}],
#   [21, {'gender_category': 'Man', 'qrel': 0.22476108}],
#   [22, {'gender_category': 'Man', 'qrel': 0.31137985}],
#   [23, {'gender_category': 'Man', 'qrel': 0.3948822}],
#   [24, {'gender_category': 'Man', 'qrel': 0.4668671}],
#   [25, {'gender_category': 'Woman', 'qrel': 0.4766657}],
#   [26, {'gender_category': 'Man', 'qrel': 0.4784891}],
#   [27, {'gender_category': 'Woman', 'qrel': 0.34168866}],
#   [28, {'gender_category': 'Man', 'qrel': 0.2258933}],
#   [29, {'gender_category': 'Woman', 'qrel': 0.44596925}],
#   [30, {'gender_category': 'Man', 'qrel': 0.3464796}],
#   [31, {'gender_category': 'Man', 'qrel': 0.4571543}],
#   [32, {'gender_category': 'Man', 'qrel': 0.38720885}],
#   [33, {'gender_category': 'Woman', 'qrel': 0.24468344}],
#   [34, {'gender_category': 'Man', 'qrel': 0.33719972}],
#   [35, {'gender_category': 'Man', 'qrel': 0.53643125}],
#   [36, {'gender_category': 'Woman', 'qrel': 0.27914345}],
#   [37, {'gender_category': 'Man', 'qrel': 0.31570247}],
#   [38, {'gender_category': 'Woman', 'qrel': 0.31201032}],
#   [39, {'gender_category': 'Man', 'qrel': 0.2753966}],
#   [40, {'gender_category': 'Woman', 'qrel': 0.4559681}],
#   [41, {'gender_category': 'Man', 'qrel': 0.43634918}],
#   [42, {'gender_category': 'Man', 'qrel': 0.5608159}],
#   [43, {'gender_category': 'Man', 'qrel': 0.35515204}],
#   [44, {'gender_category': 'Man', 'qrel': 0.42755097}],
#   [45, {'gender_category': 'Man', 'qrel': 0.62029415}],
#   [46, {'gender_category': 'Man', 'qrel': 0.26948273}],
#   [47, {'gender_category': 'Man', 'qrel': 0.47655153}],
#   [48, {'gender_category': 'Man', 'qrel': 0.32511538}],
#   [49, {'gender_category': 'Man', 'qrel': 0.48101538}],
#   [50, {'gender_category': 'Man', 'qrel': 0.2860989}],
#   [51, {'gender_category': 'Man', 'qrel': 0.44030687}],
#   [52, {'gender_category': 'Man', 'qrel': 0.38892874}],
#   [53, {'gender_category': 'Man', 'qrel': 0.31005684}],
#   [54, {'gender_category': 'Man', 'qrel': 0.44617265}],
#   [55, {'gender_category': 'Man', 'qrel': 0.6164606}],
#   [56, {'gender_category': 'Man', 'qrel': 0.6076256}],
#   [57, {'gender_category': 'Man', 'qrel': 0.3505619}],
#   [58, {'gender_category': 'Woman', 'qrel': 0.5583604}],
#   [59, {'gender_category': 'Man', 'qrel': 0.33047533}],
#   [60, {'gender_category': 'Man', 'qrel': 0.44397628}],
#   [61, {'gender_category': 'Man', 'qrel': 0.448449}],
#   [62, {'gender_category': 'Man', 'qrel': 0.4011684}],
#   [63, {'gender_category': 'Man', 'qrel': 0.47832263}],
#   [64, {'gender_category': 'Man', 'qrel': 0.371721}],
#   [65, {'gender_category': 'Man', 'qrel': 0.24650212}],
#   [66, {'gender_category': 'Man', 'qrel': 0.23532997}],
#   [67, {'gender_category': 'Man', 'qrel': 0.33872378}],
#   [68, {'gender_category': 'Man', 'qrel': 0.34880736}],
#   [69, {'gender_category': 'Man', 'qrel': 0.33026832}],
#   [70, {'gender_category': 'Man', 'qrel': 0.29961964}],
#   [71, {'gender_category': 'Woman', 'qrel': 0.25284117}],
#   [72, {'gender_category': 'Man', 'qrel': 0.3740489}],
#   [73, {'gender_category': 'Man', 'qrel': 0.46618176}],
#   [74, {'gender_category': 'Man', 'qrel': 0.3715462}],
#   [75, {'gender_category': 'Man', 'qrel': 0.40038618}],
#   [76, {'gender_category': 'Woman', 'qrel': 0.33488652}],
#   [77, {'gender_category': 'Man', 'qrel': 0.43481043}],
#   [78, {'gender_category': 'Man', 'qrel': 0.4204094}],
#   [79, {'gender_category': 'Man', 'qrel': 0.30001542}],
#   [80, {'gender_category': 'Man', 'qrel': 0.22532599}],
#   [81, {'gender_category': 'Man', 'qrel': 0.38699546}],
#   [82, {'gender_category': 'Man', 'qrel': 0.39334404}],
#   [83, {'gender_category': 'Man', 'qrel': 0.38227886}],
#   [84, {'gender_category': 'Woman', 'qrel': 0.46305355}],
#   [85, {'gender_category': 'Man', 'qrel': 0.19796191}],
#   [86, {'gender_category': 'Woman', 'qrel': 0.4503662}],
#   [87, {'gender_category': 'Man', 'qrel': 0.2532793}],
#   [88, {'gender_category': 'Man', 'qrel': 0.26831064}],
#   [89, {'gender_category': 'Man', 'qrel': 0.2936466}],
#   [90, {'gender_category': 'Woman', 'qrel': 0.5175619}],
#   [91, {'gender_category': 'Woman', 'qrel': 0.3281382}],
#   [92, {'gender_category': 'Man', 'qrel': 0.41309482}],
#   [93, {'gender_category': 'Man', 'qrel': 0.3398338}],
#   [94, {'gender_category': 'Man', 'qrel': 0.49320835}],
#   [95, {'gender_category': 'Man', 'qrel': 0.32841942}],
#   [96, {'gender_category': 'Man', 'qrel': 0.2882122}],
#   [97, {'gender_category': 'Man', 'qrel': 0.3506636}],
#   [98, {'gender_category': 'Man', 'qrel': 0.28622663}],
#   [99, {'gender_category': 'Man', 'qrel': 0.2885386}]],
#  '28': [[0, {'gender_category': 'Man', 'qrel': 0.30334318}],
#   [1, {'gender_category': 'Man', 'qrel': 0.30479053}],
#   [2, {'gender_category': 'Man', 'qrel': 0.45942733}],
#   [3, {'gender_category': 'Man', 'qrel': 0.27401802}],
#   [4, {'gender_category': 'Man', 'qrel': 0.29654545}],
#   [5, {'gender_category': 'Man', 'qrel': 0.34803268}],
#   [6, {'gender_category': 'Man', 'qrel': 0.3310975}],
#   [7, {'gender_category': 'Man', 'qrel': 0.33696705}],
#   [8, {'gender_category': 'Woman', 'qrel': 0.43804768}],
#   [9, {'gender_category': 'Man', 'qrel': 0.44572663}],
#   [10, {'gender_category': 'Woman', 'qrel': 0.42190984}],
#   [11, {'gender_category': 'Man', 'qrel': 0.35733193}],
#   [12, {'gender_category': 'Man', 'qrel': 0.34237295}],
#   [13, {'gender_category': 'Man', 'qrel': 0.28343654}],
#   [14, {'gender_category': 'Man', 'qrel': 0.4618199}],
#   [15, {'gender_category': 'Woman', 'qrel': 0.41044617}],
#   [16, {'gender_category': 'Woman', 'qrel': 0.57402503}],
#   [17, {'gender_category': 'Woman', 'qrel': 0.39619765}],
#   [18, {'gender_category': 'Man', 'qrel': 0.32934362}],
#   [19, {'gender_category': 'Woman', 'qrel': 0.22064358}],
#   [20, {'gender_category': 'Man', 'qrel': 0.44185033}],
#   [21, {'gender_category': 'Man', 'qrel': 0.22476108}],
#   [22, {'gender_category': 'Man', 'qrel': 0.31137985}],
#   [23, {'gender_category': 'Man', 'qrel': 0.3948822}],
#   [24, {'gender_category': 'Man', 'qrel': 0.4668671}],
#   [25, {'gender_category': 'Woman', 'qrel': 0.4766657}],
#   [26, {'gender_category': 'Man', 'qrel': 0.4784891}],
#   [27, {'gender_category': 'Woman', 'qrel': 0.34168866}],
#   [28, {'gender_category': 'Man', 'qrel': 0.2258933}],
#   [29, {'gender_category': 'Woman', 'qrel': 0.44596925}],
#   [30, {'gender_category': 'Man', 'qrel': 0.3464796}],
#   [31, {'gender_category': 'Man', 'qrel': 0.4571543}],
#   [32, {'gender_category': 'Man', 'qrel': 0.38720885}],
#   [33, {'gender_category': 'Woman', 'qrel': 0.24468344}],
#   [34, {'gender_category': 'Man', 'qrel': 0.33719972}],
#   [35, {'gender_category': 'Man', 'qrel': 0.53643125}],
#   [36, {'gender_category': 'Woman', 'qrel': 0.27914345}],
#   [37, {'gender_category': 'Man', 'qrel': 0.31570247}],
#   [38, {'gender_category': 'Woman', 'qrel': 0.31201032}],
#   [39, {'gender_category': 'Man', 'qrel': 0.2753966}],
#   [40, {'gender_category': 'Woman', 'qrel': 0.4559681}],
#   [41, {'gender_category': 'Man', 'qrel': 0.43634918}],
#   [42, {'gender_category': 'Man', 'qrel': 0.5608159}],
#   [43, {'gender_category': 'Man', 'qrel': 0.35515204}],
#   [44, {'gender_category': 'Man', 'qrel': 0.42755097}],
#   [45, {'gender_category': 'Man', 'qrel': 0.62029415}],
#   [46, {'gender_category': 'Man', 'qrel': 0.26948273}],
#   [47, {'gender_category': 'Man', 'qrel': 0.47655153}],
#   [48, {'gender_category': 'Man', 'qrel': 0.32511538}],
#   [49, {'gender_category': 'Man', 'qrel': 0.48101538}],
#   [50, {'gender_category': 'Man', 'qrel': 0.2860989}],
#   [51, {'gender_category': 'Man', 'qrel': 0.44030687}],
#   [52, {'gender_category': 'Man', 'qrel': 0.38892874}],
#   [53, {'gender_category': 'Man', 'qrel': 0.31005684}],
#   [54, {'gender_category': 'Man', 'qrel': 0.44617265}],
#   [55, {'gender_category': 'Man', 'qrel': 0.6164606}],
#   [56, {'gender_category': 'Man', 'qrel': 0.6076256}],
#   [57, {'gender_category': 'Man', 'qrel': 0.3505619}],
#   [58, {'gender_category': 'Woman', 'qrel': 0.5583604}],
#   [59, {'gender_category': 'Man', 'qrel': 0.33047533}],
#   [60, {'gender_category': 'Man', 'qrel': 0.44397628}],
#   [61, {'gender_category': 'Man', 'qrel': 0.448449}],
#   [62, {'gender_category': 'Man', 'qrel': 0.4011684}],
#   [63, {'gender_category': 'Man', 'qrel': 0.47832263}],
#   [64, {'gender_category': 'Man', 'qrel': 0.371721}],
#   [65, {'gender_category': 'Man', 'qrel': 0.24650212}],
#   [66, {'gender_category': 'Man', 'qrel': 0.23532997}],
#   [67, {'gender_category': 'Man', 'qrel': 0.33872378}],
#   [68, {'gender_category': 'Man', 'qrel': 0.34880736}],
#   [69, {'gender_category': 'Man', 'qrel': 0.33026832}],
#   [70, {'gender_category': 'Man', 'qrel': 0.29961964}],
#   [71, {'gender_category': 'Woman', 'qrel': 0.25284117}],
#   [72, {'gender_category': 'Man', 'qrel': 0.3740489}],
#   [73, {'gender_category': 'Man', 'qrel': 0.46618176}],
#   [74, {'gender_category': 'Man', 'qrel': 0.3715462}],
#   [75, {'gender_category': 'Man', 'qrel': 0.40038618}],
#   [76, {'gender_category': 'Woman', 'qrel': 0.33488652}],
#   [77, {'gender_category': 'Man', 'qrel': 0.43481043}],
#   [78, {'gender_category': 'Man', 'qrel': 0.4204094}],
#   [79, {'gender_category': 'Man', 'qrel': 0.30001542}],
#   [80, {'gender_category': 'Man', 'qrel': 0.22532599}],
#   [81, {'gender_category': 'Man', 'qrel': 0.38699546}],
#   [82, {'gender_category': 'Man', 'qrel': 0.39334404}],
#   [83, {'gender_category': 'Man', 'qrel': 0.38227886}],
#   [84, {'gender_category': 'Woman', 'qrel': 0.46305355}],
#   [85, {'gender_category': 'Man', 'qrel': 0.19796191}],
#   [86, {'gender_category': 'Woman', 'qrel': 0.4503662}],
#   [87, {'gender_category': 'Man', 'qrel': 0.2532793}],
#   [88, {'gender_category': 'Man', 'qrel': 0.26831064}],
#   [89, {'gender_category': 'Man', 'qrel': 0.2936466}],
#   [90, {'gender_category': 'Woman', 'qrel': 0.5175619}],
#   [91, {'gender_category': 'Woman', 'qrel': 0.3281382}],
#   [92, {'gender_category': 'Man', 'qrel': 0.41309482}],
#   [93, {'gender_category': 'Man', 'qrel': 0.3398338}],
#   [94, {'gender_category': 'Man', 'qrel': 0.49320835}],
#   [95, {'gender_category': 'Man', 'qrel': 0.32841942}],
#   [96, {'gender_category': 'Man', 'qrel': 0.2882122}],
#   [97, {'gender_category': 'Man', 'qrel': 0.3506636}],
#   [98, {'gender_category': 'Man', 'qrel': 0.28622663}],
#   [99, {'gender_category': 'Man', 'qrel': 0.2885386}]]}

# %%
eval_reulst = []
from tqdm import tqdm
for ranking_id, ranking in tqdm(llm_ranking.items()):
    result = ranking

    nDCG5 = calculate_ndcg(result, n=5)
    awrf5 = calculate_awrf(result, dataset_distribution, 'gender_category', n=5)

    nDCG10 = calculate_ndcg(result, n=10)
    awrf10 = calculate_awrf(result, dataset_distribution, 'gender_category', n=10)

    nDCG20 = calculate_ndcg(result, n=20)
    awrf20 = calculate_awrf(result, dataset_distribution, 'gender_category', n=20)

    nDCG50 = calculate_ndcg(result, n=50)
    awrf50 = calculate_awrf(result, dataset_distribution, 'gender_category', n=50)

    # eval_reulst.append([topic_id, query, nDCG5, awrf5, nDCG10, awrf10, nDCG20, awrf20, nDCG50, awrf50])
    eval_reulst.append([nDCG5,nDCG10,nDCG20,nDCG50, awrf5,awrf10,awrf20,awrf50])

eval_df = pd.DataFrame(eval_reulst, columns=["nDCG5","nDCG10","nDCG20","nDCG50", "awrf5","awrf10","awrf20","awrf50"])
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d1afd2f98b44> in <module>
#       5
#       6     nDCG5 = calculate_ndcg(result, n=5)
# ----> 7     awrf5 = calculate_awrf(result, dataset_distribution, 'gender_category', n=5)
#       8
#       9     nDCG10 = calculate_ndcg(result, n=10)
#
# <ipython-input-18-72ae48795f02> in calculate_awrf(ranked_list, expected_distribution, attribute, n)
#      39     for index, row in enumerate(ranked_list):
#      40         if index<n:
# ---> 41             if row[attribute]:
#      42                 current_distribution[row[attribute]]+= disc(index+1)
#      43             else:
#
# TypeError: list indices must be integers or slices, not str

# %%
eval_df.to_csv("LLMresults.csv",index=False)
